# %% [markdown]
# ### Practical Section

# %% [markdown]
# In this section, we will be looking into one of the practical reinforcement learning problems populary known as the Cartpole Problem using OpenAI Gym for our learning environment.\
# The carpole problem consists of an inverted pendulum mounted on a cart. At any given state, the environment returns four observations to the agent. These observations are the position of the cart, velocity of the cart, angle of the pole and lastly the angular velocity of the pole. The agent using these observations has to decide on one of two possible actions, either move the cart to the left  or right.
# The goal of the agent is to balance the pole and keep it balanced for longer period of time. The agent recieves a  reward of +1 at each time step its able to keep the pole upright and -1 if it fails. The environment returns 'done' if the agent fails to balance the pole or if the maximum time-step for an episode is reached. In the cartpole environment,the agent fails to balance:
#
# 1. if the angle of the pole is greater than $\pm 12^{\circ}$
# 2. Cart position is exceeds $\pm 2.4$
#
#
# $\bullet$ We will build our agent on SARSA-learning algorithm, therefore the update rule for our Q values is:
# \begin{equation}
# Q(s_{t},a_{t})_{\pi} \leftarrow Q(s_t, a_t)_{\pi} + \alpha \big[ R_{t+1} +  \gamma Q(s_{t+1},a_{t+1})_{\pi} - Q(s_{t},a_{t})_{\pi}\big]
# \end{equation}
# $\bullet$ The agent will be trained using $\epsilon$-greedy exploration. \
# $\bullet$ We will be using Cartpole version 1(CartPole-v1)\
# $\bullet$ We will set our maximum step per epiode to 450 since CartPole-v1 comes with a default maximum step of 500

# %% [markdown]
# ### Importing modules
# We start by importing the needed packages.
# Gym is for our Cartpole environment

# %%
import gym
import numpy as np
import math
import matplotlib.pyplot as plt
import time
import random

# %%
sarsa_seed = 50

# %%
random.seed(sarsa_seed)

# %%
#random.seed(1337)# we set random seed for consistent results

# %% [markdown]
# ### Cartpole Agent
# We create our cartpole agent here.
# We initialize our parameters, try to reduce the dimension of the observation space domain. We then discretize the observation space by creating bins.\
# We create our Q-value look up table to help us in the action selection.

# %%
class Q_Cartpole_Agent():
    def __init__(self, num_buckets=(1, 1, 6, 12), num_episodes=1000, episode_max_step=450, learning_rate=0.001, min_explore_rate=0.01, discount=1.0, decay_rate=25):
        self.buckets = num_buckets
        self.num_episodes = num_episodes
        self.learning_rate = learning_rate
        self.min_explore_rate = min_explore_rate
        self.discount = discount
        self.decay_rate = decay_rate
        self.episode_max_step = episode_max_step
        self.env2_s = gym.make('CartPole-v1')
        self.env2_s.seed(sarsa_seed)
        self.env2_s.action_space.seed(sarsa_seed)
        
        
         # [position, velocity, angle, angular velocity]
        self.upper_bounds = [self.env2_s.observation_space.high[0], 0.5, self.env2_s.observation_space.high[2], math.radians(50) / 1.]
        self.lower_bounds = [self.env2_s.observation_space.low[0], -0.5, self.env2_s.observation_space.low[2], -math.radians(50) / 1.]

        self.Sarsa_table = np.zeros(self.buckets + (self.env2_s.action_space.n,))
        
        
    def discretize(self, observation):
        discretized = list()
        for i in range(len(observation)):
            scale = (observation[i] + abs(self.lower_bounds[i])) / (self.upper_bounds[i] - self.lower_bounds[i])
            new_observation = int(round((self.buckets[i] - 1) * scale))
            new_observation = min(self.buckets[i] - 1, max(0, new_observation))
            discretized.append(new_observation)
        return tuple(discretized)
    
    def choose_action(self, state):
        np.random.seed(sarsa_seed)
        if (np.random.random() < self.explore_rate):
            return self.env2_s.action_space.sample() 
        else:
            return np.argmax(self.Sarsa_table[state])
     
    def update_Sarsa_table(self, state, action, reward, new_state,new_action):
        self.Sarsa_table[state][action] += self.learning_rate * (reward + self.discount * (self.Sarsa_table[new_state][new_action]) - self.Sarsa_table[state][action])
   

    def loss(self, state, action, reward, new_state,new_action): #defining the error using Mean squared error
        m_s_error = (reward + self.discount * (self.Sarsa_table[new_state][new_action]) - self.Sarsa_table[state][action])**2
        return m_s_error
    

    def set_explore_rate(self, t):
        return max(self.min_explore_rate, min(1., 1. - math.log10((t + 1) / self.decay_rate)))
    
        
    
    def train(self):
        total_rewards = []
        err_train = []
        for episode in range(self.num_episodes):
            current_state = self.discretize(self.env2_s.reset())
            episode_rewards = 0
            self.explore_rate = self.set_explore_rate(episode)
            done = False
            err_episode = []
            
            for time_step in range(self.episode_max_step ):
                #env1.render()
                
                action = self.choose_action(current_state)
                
                new_state, reward, done, _ = self.env2_s.step(action)
                
                new_state = self.discretize(new_state)
                new_action = self.choose_action(new_state)
                self.update_Sarsa_table(current_state, action, reward, new_state,new_action)
                err = self.loss(current_state, action, reward, new_state , new_action)
                #incrementing reward
                episode_rewards += reward
                
                current_state = new_state
                
                err_episode.append(err)
                
                if done == True:
                
                    break
                
        #appending episode reward to the total reward
            total_rewards.append(episode_rewards)
            
            err_train.append(np.mean(err_episode))
        #Maximum =   max(total_rewards)  
        print('Training completed')
        print('Maximum reward of training is {} in episode {}'.format(max(total_rewards),total_rewards.index(max(total_rewards)))) 
        return total_rewards , err_train
           
        
        
    def Test(self):
        rewards_test = list()
        err_test = []
        for episode in range(101):
            current_state = self.env2_s.reset()
            current_state = self.discretize(current_state)
            episode_rewards_test = 0
            err2 = []
            for time_step in range(self.episode_max_step):
                self.env2_s.render() 
                action = self.choose_action(current_state)
                new_state, reward, done, _ = self.env2_s.step(action)
                new_state = self.discretize(new_state)
                new_action = self.choose_action(new_state)
                current_state = new_state
                self.update_Sarsa_table(current_state, action, reward, new_state,new_action)
                t_err = self.loss(current_state, action, reward, new_state , new_action)
                episode_rewards_test += reward
                
                err2.append(t_err)
                
                if done == True:
                    print('Episode:{}/{} completed with a total reward of {}'.format(episode, 100, episode_rewards_test))
                    break
                
          #appending episode reward to the total reward
            rewards_test.append(episode_rewards_test)
            
            err_test.append(np.mean(err2))
    
          #Getting the average
        sum_rewards = (sum(i for i in rewards_test)) /len(rewards_test)

        continuous_rewards = (sum(rewards_test))/(len(rewards_test)*self.episode_max_step)
        
        
        print('Maximum reward obtained is {} in episode {}'.format(max(rewards_test), rewards_test.index(max(rewards_test))))
        print('Average reward is {}'.format(sum_rewards))
        print('Countinous form  reward is {}'.format(continuous_rewards))
        
        return rewards_test ,err_test
    
        self.env2_s.close()

        
    
if __name__ == "__main__":
    agent = Q_Cartpole_Agent()
    #agent.train()
    #agent.Test()
    train_agent = agent.train()
    test_agent = agent.Test()
# Out:
# Training completed
# Maximum reward of training is 70.0 in episode 712
# Episode:0/100 completed with a total reward of 32.0
# Episode:1/100 completed with a total reward of 24.0
# Episode:2/100 completed with a total reward of 19.0
# Episode:3/100 completed with a total reward of 21.0
# Episode:4/100 completed with a total reward of 28.0
# Episode:5/100 completed with a total reward of 19.0
# Episode:6/100 completed with a total reward of 19.0
# Episode:7/100 completed with a total reward of 21.0
# Episode:8/100 completed with a total reward of 22.0
# Episode:9/100 completed with a total reward of 32.0
# Episode:10/100 completed with a total reward of 17.0
# Episode:11/100 completed with a total reward of 19.0
# Episode:12/100 completed with a total reward of 23.0
# Episode:13/100 completed with a total reward of 22.0
# Episode:14/100 completed with a total reward of 29.0
# Episode:15/100 completed with a total reward of 19.0
# Episode:16/100 completed with a total reward of 19.0
# Episode:17/100 completed with a total reward of 26.0
# Episode:18/100 completed with a total reward of 17.0
# Episode:19/100 completed with a total reward of 61.0
# Episode:20/100 completed with a total reward of 28.0
# Episode:21/100 completed with a total reward of 17.0
# Episode:22/100 completed with a total reward of 20.0
# Episode:23/100 completed with a total reward of 28.0
# Episode:24/100 completed with a total reward of 21.0
# Episode:25/100 completed with a total reward of 25.0
# Episode:26/100 completed with a total reward of 19.0
# Episode:27/100 completed with a total reward of 26.0
# Episode:28/100 completed with a total reward of 18.0
# Episode:29/100 completed with a total reward of 25.0
# Episode:30/100 completed with a total reward of 27.0
# Episode:31/100 completed with a total reward of 21.0
# Episode:32/100 completed with a total reward of 24.0
# Episode:33/100 completed with a total reward of 24.0
# Episode:34/100 completed with a total reward of 22.0
# Episode:35/100 completed with a total reward of 17.0
# Episode:36/100 completed with a total reward of 19.0
# Episode:37/100 completed with a total reward of 28.0
# Episode:38/100 completed with a total reward of 27.0
# Episode:39/100 completed with a total reward of 20.0
# Episode:40/100 completed with a total reward of 25.0
# Episode:41/100 completed with a total reward of 32.0
# Episode:42/100 completed with a total reward of 19.0
# Episode:43/100 completed with a total reward of 22.0
# Episode:44/100 completed with a total reward of 17.0
# Episode:45/100 completed with a total reward of 24.0
# Episode:46/100 completed with a total reward of 17.0
# Episode:47/100 completed with a total reward of 25.0
# Episode:48/100 completed with a total reward of 26.0
# Episode:49/100 completed with a total reward of 27.0
# Episode:50/100 completed with a total reward of 22.0
# Episode:51/100 completed with a total reward of 21.0
# Episode:52/100 completed with a total reward of 17.0
# Episode:53/100 completed with a total reward of 22.0
# Episode:54/100 completed with a total reward of 18.0
# Episode:55/100 completed with a total reward of 27.0
# Episode:56/100 completed with a total reward of 68.0
# Episode:57/100 completed with a total reward of 29.0
# Episode:58/100 completed with a total reward of 19.0
# Episode:59/100 completed with a total reward of 21.0
# Episode:60/100 completed with a total reward of 22.0
# Episode:61/100 completed with a total reward of 27.0
# Episode:62/100 completed with a total reward of 23.0
# Episode:63/100 completed with a total reward of 64.0
# Episode:64/100 completed with a total reward of 20.0
# Episode:65/100 completed with a total reward of 66.0
# Episode:66/100 completed with a total reward of 23.0
# Episode:67/100 completed with a total reward of 21.0
# Episode:68/100 completed with a total reward of 24.0
# Episode:69/100 completed with a total reward of 29.0
# Episode:70/100 completed with a total reward of 28.0
# Episode:71/100 completed with a total reward of 20.0
# Episode:72/100 completed with a total reward of 25.0
# Episode:73/100 completed with a total reward of 19.0
# Episode:74/100 completed with a total reward of 64.0
# Episode:75/100 completed with a total reward of 22.0
# Episode:76/100 completed with a total reward of 23.0
# Episode:77/100 completed with a total reward of 22.0
# Episode:78/100 completed with a total reward of 20.0
# Episode:79/100 completed with a total reward of 24.0
# Episode:80/100 completed with a total reward of 29.0
# Episode:81/100 completed with a total reward of 23.0
# Episode:82/100 completed with a total reward of 25.0
# Episode:83/100 completed with a total reward of 22.0
# Episode:84/100 completed with a total reward of 22.0
# Episode:85/100 completed with a total reward of 21.0
# Episode:86/100 completed with a total reward of 25.0
# Episode:87/100 completed with a total reward of 17.0
# Episode:88/100 completed with a total reward of 27.0
# Episode:89/100 completed with a total reward of 17.0
# Episode:90/100 completed with a total reward of 17.0
# Episode:91/100 completed with a total reward of 30.0
# Episode:92/100 completed with a total reward of 17.0
# Episode:93/100 completed with a total reward of 20.0
# Episode:94/100 completed with a total reward of 18.0
# Episode:95/100 completed with a total reward of 20.0
# Episode:96/100 completed with a total reward of 23.0
# Episode:97/100 completed with a total reward of 21.0
# Episode:98/100 completed with a total reward of 18.0
# Episode:99/100 completed with a total reward of 23.0
# Episode:100/100 completed with a total reward of 22.0
# Maximum reward obtained is 68.0 in episode 56
# Average reward is 24.613861386138613
# Countinous form  reward is 0.054697469746974696

# %% [markdown]
# ## Plotting Results

# %%
#plotting rewards from 
plt.figure(figsize=(8, 8))
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.plot(np.array(train_agent[0]))
plt.savefig('cartpole_Sarsa_train_M2')

# %%
#plotting error
plt.figure(figsize=(8, 8))
plt.xlabel("Episodes")
plt.ylabel("Training error")
plt.plot(np.array(train_agent[1]))
plt.savefig('cartpole_Sarsa_error_M2')

# %%
#plotting rewards from testing
plt.figure(figsize=(8, 8))
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.plot(np.array(test_agent[0]))
plt.savefig('cartpole_Sarsa_test_M2')

# %%
#plotting errors of testing
plt.figure(figsize=(8, 8))
plt.xlabel("Episodes")
plt.ylabel("Testing error")
plt.plot(np.array(test_agent[1]))
plt.savefig('cartpole_Sarsa_errTest_M2')

# %% [markdown]
# ### Rewards
